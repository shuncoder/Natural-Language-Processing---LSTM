# %% [markdown]
# TẠO DATASET (Crawl dữ liệu)

# %%
# !pip install requests beautifulsoup4 pandas

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
def crawl_vnexpress(category_url, label, num_pages):
  articles = []
  headers = {"User-Agent": "Mozilla/5.0"}

  for page in range(1, num_pages + 1):
    url = f"{category_url}-p{page}"
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, "html.parser")

    for item in soup.select("div.list-news-subfolder article"):
      title = item.select_one("h3.title-news a")
      summary = item.select_one("p.description a")

      if title and summary:
        articles.append({
            "title": title.text.strip(),
            "summary": summary.text.strip(),
            "label": label
        })
    time.sleep(1)

  return articles

# %%
def crawl_zingnews(category_url, label, num_pages):
  articles = []
  headers = {"User-Agent": "Mozilla/5.0"}

  for page in range(1, num_pages + 1):
    url = category_url.replace("trang1.html", f"trang{page}.html")
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, "html.parser")

    for item in soup.select("article"):
      title = item.select_one("h3.article-title a")
      summary = item.select_one("p.article-summary")

      if title and summary:
        articles.append({
            "title": title.text.strip(),
            "summary": summary.text.strip(),
            "label": label
        })
    time.sleep(1)

  return articles

# %%
def crawl_vietnamnet(category_url, label, num_pages):
  articles = []
  headers = {"User-Agent": "Mozilla/5.0"}

  for page in range(1, num_pages + 1):
    url = f"{category_url}?p={page}"
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, "html.parser")

    for item in soup.select("div.horizontalPost"):
      title = item.select_one("h3.horizontalPost__main-title a")
      summary = item.select_one("div.horizontalPost__main-desc p")

      if title and summary:
        articles.append({
            "title": title.text.strip(),
            "summary": summary.text.strip(),
            "label": label
        })
    time.sleep(1)

  return articles

# %%
def crawl_dantri(category_url, label, num_pages):
  articles = []
  headers = {"User-Agent": "Mozilla/5.0"}

  for page in range(1, num_pages + 1):
    url = category_url.replace(".htm", f"/trang-{page}.htm")
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, "html.parser")

    for item in soup.select("article.article-item"):
      title = item.select_one("h3.article-title a")
      summary = item.select_one("div.article-excerpt")

      if title and summary:
        articles.append({
            "title": title.text.strip(),
            "summary": summary.text.strip(),
            "label": label
        })
    time.sleep(1)

  return articles

# data1 = []
# data1 += crawl_dantri("https://dantri.com.vn/kinh-doanh.htm", "Chính trị", num_pages=3)

# dk = pd.DataFrame(data1)
# dk.head()

# %%
def crawl_laodong(category_url, label, num_pages):
  articles = []
  headers = {"User-Agent": "Mozilla/5.0"}

  for page in range(1, num_pages + 1):
    url = f"{category_url}?p={page}"
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, "html.parser")

    for item in soup.select("article.v4"):
      title = item.select_one("a.link-title h2")
      summary = item.select_one("div.chapeau")

      if title and summary:
        articles.append({
            "title": title.text.strip(),
            "summary": summary.text.strip(),
            "label": label
        })
    time.sleep(1)

  return articles

# %%
def crawl_cafef(category_url, label, num_pages):
  articles = []
  headers = {"User-Agent": "Mozilla/5.0"}

  for page in range(1, num_pages + 1):
    url = category_url.replace("trang-1.html", f"trang-{page}.html")
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, "html.parser")

    for item in soup.select("div.tlitem"):
      title = item.select_one("h3 a")
      summary = item.select_one("p.sapo")

      if title and summary:
        articles.append({
            "title": title.text.strip(),
            "summary": summary.text.strip(),
            "label": label
        })
    time.sleep(1)

  return articles

# data1 = []
# data1 += crawl_cafef("https://cafef.vn/the-gioi-cong-nghe/trang-1.html", "Công nghệ", num_pages=3)

# dk = pd.DataFrame(data1)
# dk.head()

# %%
data = []
num_pages = 30

# %%
data += crawl_vnexpress("https://vnexpress.net/thoi-su", "Thời sự", num_pages)
data += crawl_vnexpress("https://vnexpress.net/the-thao", "Thể thao", num_pages)
data += crawl_vnexpress("https://vnexpress.net/kinh-doanh", "Kinh tế", num_pages)
data += crawl_vnexpress("https://vnexpress.net/so-hoa", "Công nghệ", num_pages)
data += crawl_vnexpress("https://vnexpress.net/suc-khoe", "Y tế", num_pages)
data += crawl_vnexpress("https://vnexpress.net/giao-duc", "Giáo dục", num_pages)
data += crawl_vnexpress("https://vnexpress.net/giai-tri", "Giải trí", num_pages)
data += crawl_vnexpress("https://vnexpress.net/doi-song", "Đời sống", num_pages)
data += crawl_vnexpress("https://vnexpress.net/the-gioi", "Thế giới", num_pages)
data += crawl_vnexpress("https://vnexpress.net/phap-luat", "Pháp luật", num_pages)
data += crawl_vnexpress("https://vnexpress.net/khoa-hoc-cong-nghe", "Công nghệ", num_pages)

data += crawl_zingnews("https://zingnews.vn/the-thao/trang1.html", "Thể thao", num_pages)
data += crawl_zingnews("https://zingnews.vn/cong-nghe/trang1.html", "Công nghệ", num_pages)
data += crawl_zingnews("https://zingnews.vn/the-gioi/trang1.html", "Thế giới", num_pages)
data += crawl_zingnews("https://zingnews.vn/giao-duc/trang1.html", "Giáo dục", num_pages)
data += crawl_zingnews("https://zingnews.vn/doi-song/trang1.html", "Đời sống", num_pages)
data += crawl_zingnews("https://zingnews.vn/suc-khoe/trang1.html", "Y tế", num_pages)

data += crawl_vietnamnet("https://vietnamnet.vn/cong-nghe", "Công nghệ", num_pages)
data += crawl_vietnamnet("https://vietnamnet.vn/thoi-su", "Thời sự", num_pages)
data += crawl_vietnamnet("https://vietnamnet.vn/the-thao", "Thể thao", num_pages)
data += crawl_vietnamnet("https://vietnamnet.vn/giao-duc", "Giáo dục", num_pages)
data += crawl_vietnamnet("https://vietnamnet.vn/suc-khoe", "Y tế", num_pages)
data += crawl_vietnamnet("https://vietnamnet.vn/doi-song", "Đời sống", num_pages)
data += crawl_vietnamnet("https://vietnamnet.vn/van-hoa-giai-tri", "Giải trí", num_pages)
data += crawl_vietnamnet("https://vietnamnet.vn/chinh-tri", "Chính trị", num_pages)
data += crawl_vietnamnet("https://vietnamnet.vn/the-gioi", "Thế giới", num_pages)
data += crawl_vietnamnet("https://vietnamnet.vn/phap-luat", "Pháp luật", num_pages)

data += crawl_dantri("https://dantri.com.vn/kinh-doanh.htm", "Kinh tế", num_pages)
data += crawl_dantri("https://dantri.com.vn/the-gioi.htm", "Thế giới", num_pages)
data += crawl_dantri("https://dantri.com.vn/xa-hoi.htm", "Thời sự", num_pages)
data += crawl_dantri("https://dantri.com.vn/giai-tri.htm", "Giải trí", num_pages)
data += crawl_dantri("https://dantri.com.vn/the-thao.htm", "Thể thao", num_pages)
data += crawl_dantri("https://dantri.com.vn/suc-khoe.htm", "Y tế", num_pages)
data += crawl_dantri("https://dantri.com.vn/cong-nghe.htm", "Công nghệ", num_pages)
data += crawl_dantri("https://dantri.com.vn/giao-duc.htm", "Giáo dục", num_pages)
data += crawl_dantri("https://dantri.com.vn/phap-luat.htm", "Pháp luật", num_pages)

data += crawl_laodong("https://laodong.vn/kinh-doanh", "Kinh tế", num_pages)
data += crawl_laodong("https://laodong.vn/xa-hoi", "Thời sự", num_pages)
data += crawl_laodong("https://laodong.vn/thoi-su", "Thời sự", num_pages)
data += crawl_laodong("https://laodong.vn/phap-luat", "Pháp luật", num_pages)
data += crawl_laodong("https://laodong.vn/the-thao", "Thể thao", num_pages)
data += crawl_laodong("https://laodong.vn/the-gioi", "Thế giới", num_pages)
data += crawl_laodong("https://laodong.vn/cong-nghe", "Công nghệ", num_pages)
data += crawl_laodong("https://laodong.vn/suc-khoe", "Y tế", num_pages)
data += crawl_laodong("https://laodong.vn/giao-duc", "Giáo dục", num_pages)
data += crawl_laodong("https://laodong.vn/van-hoa-giai-tri", "Giải trí", num_pages)

data += crawl_cafef("https://cafef.vn/the-gioi-cong-nghe/trang-1.html", "Công nghệ", num_pages)
data += crawl_cafef("https://cafef.vn/xa-hoi/trang-1.html", "Thời sự", num_pages)
data += crawl_cafef("https://cafef.vn/kinh-te-so/trang-1.html", "Kinh tế", num_pages)
data += crawl_cafef("https://cafef.vn/doanh-nghiep/trang-1.html", "Kinh tế", num_pages)
data += crawl_cafef("https://cafef.vn/giao-duc/trang-1.html", "Giáo dục", num_pages)
data += crawl_cafef("https://cafef.vn/y-te/trang-1.html", "Y tế", num_pages)
data += crawl_cafef("https://cafef.vn/phap-luat/trang-1.html", "Pháp luật", num_pages)
data += crawl_cafef("https://cafef.vn/giai-tri/trang-1.html", "Giải trí", num_pages)

df = pd.DataFrame(data)
df.head()
# Out:
#                                                title  \
# 0  73% người cao tuổi không lương hưu, trợ cấp bả...
# 1  Đề xuất thu phí cao tốc Bến Lức - Long Thành 2...
# 2   Quốc hội khai mạc, bắt đầu xem xét sửa Hiến pháp
# 3                  Giấc mơ về những mái nhà lành lặn
# 4                            Hải Phòng 100 năm trước
#
#                                              summary    label
# 0  Phần lớn người già không hưu trí, trợ cấp bảo ...  Thời sự
# 1  Tổng công ty Đầu tư phát triển đường cao tốc V...  Thời sự
# 2  Sáng 5/5, Quốc hội khóa 15 khai mạc kỳ họp thứ...  Thời sự
# 3  Hà TĩnhNhiều năm qua, người lính già 98 tuổi v...  Thời sự
# 4  Hải PhòngHải Phòng xưa kia là làng chài nhỏ ve...  Thời sự

# %%
print(len(df))
# Out:
# 22327

# %%
df.to_csv("dataset.csv", index=False)
from google.colab import files
files.download("dataset.csv")
